# %%
pip install xlrd
# Out:
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------- ----------------------- 41.0/96.5 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing pandas as pd 

import pandas as pd 
  
# Read and store content 
# of an excel file  
read_file = pd.read_excel ("C:/Users/lluis/Desktop/Documents/IronHack/Week2/Day6/MiniProject2/GSAF5.xls") 

# into csv file 
read_file.to_csv ("C:/Users/lluis/Desktop/Documents/IronHack/Week2/Day6/MiniProject2/GSAF5.csv")
    
# read csv file and convert  
# into a dataframe object 
df = pd.DataFrame(pd.read_csv("C:/Users/lluis/Desktop/Documents/IronHack/Week2/Day6/MiniProject2/GSAF5.csv")) 
  
# show the dataframe 
df
# Out:
#       Unnamed: 0         Date    Year        Type    Country  \
# 0              0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA
# 1              1  04 Mar 2024  2024.0  Unprovoked        USA
# 2              2  02 Mar-2024  2024.0  Unprovoked        USA
# 3              3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA
# 4              4  14 Feb-2024  2024.0  Unprovoked      INDIA
# ...          ...          ...     ...         ...        ...
# 6964        6964          NaN     NaN         NaN        NaN
# 6965        6965          NaN     NaN         NaN        NaN
# 6966        6966          NaN     NaN         NaN        NaN
# 6967        6967          NaN     NaN         NaN        NaN
# 6968        6968          NaN     NaN         NaN        NaN
#
#                   State                          Location  Activity  \
# 0            Queensland                     Bargara Beach  Swimming
# 1                Hawaii                Old Man's, Waikiki   Surfing
# ...

# %%
import re

# Data Cleaning:

# Check for missing or null values
print(df.isnull().sum())

# Handle missing or null values
#df = df.fillna('Unknown')
# Out:
# Unnamed: 0           0
# Date                25
# Year                27
# Type                43
# Country             75
# State              507
# Location           590
# Activity           611
# Name               245
# Sex                604
# Age               3019
# Injury              60
# Unnamed: 11        587
# Time              3551
# Species           3157
# Source              44
# pdf                170
# href formula       150
# href               173
# Case Number        171
# Case Number.1      172
# original order     170
# Unnamed: 21       6968
# Unnamed: 22       6967
# dtype: int64
